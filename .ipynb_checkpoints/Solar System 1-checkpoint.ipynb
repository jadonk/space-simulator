# %%
import Plots
import NBodySimulator
import StaticArrays
import HTTP
import CSV
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
const G = 6.67408e-11 # kg^-1 m^3 s^-2
const t0 = 2458976.500000000 # A.D. 2020-May-07 00:00:00.0000 TDB (units = Earth days)
const au = 1.49597870700e11 # m/au
const day = 86400.0 # s/day
struct pd
    b
    r
end

# %% [markdown]
# Sun mass data from https://en.wikipedia.org/wiki/Sun
# Planet mass data from https://ssd.jpl.nasa.gov/?planet_phys_par
# Position data from https://ssd.jpl.nasa.gov/horizons.cgi#results

# %%
function pdata(command, mass)
    v = Vector{Float64}(undef,6)
    r = HTTP.request("GET", "https://ssd.jpl.nasa.gov/horizons_batch.cgi?" *
        "batch=1&MAKE_EPHEM='YES'&TABLE_TYPE='VECTORS'&START_TIME='2020-05-07'&" *
        "STOP_TIME='2020-12-30'&STEP_SIZE='30%20d'&CSV_FORMAT='YES'&" *
        "CENTER='@0'&COMMAND='" * command * "'")
    result = String(r.body)
    m = match(r"\$\$SOE\n([^\$]*)\$\$EOE\n", result)
    c = CSV.read(IOBuffer(m[1]), header=["JDTDB", "TDB", "X", "Y", "Z", "VX", "VY", "VZ", "LT", "RG", "RR"])
    for i in 3:8
        v[i-2] = c[1,i]*1000.0 # Convert km to m for first row
    end
    return(pd(NBodySimulator.MassBody(
                StaticArrays.SVector(v[1], v[2], v[3]),
                StaticArrays.SVector(v[4], v[5], v[6]), 
                mass), result))
end
sun = pdata("10", 1988500e24)
mercury = pdata("199", 0.330114e24)
venus = pdata("299", 4.86747e24)
earth = pdata("399", 5.97237e24)
mars = pdata("499", 0.641712e24)
jupiter = pdata("599", 1898.187e24)
saturn = pdata("699", 568.336e24)
uranus = pdata("799", 86.8127e24)
neptune = pdata("899", 102.4126e24)
pluto = pdata("999", 0.013030e24)
# Out:
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 1. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 2. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 3. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 4. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 5. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 6. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 7. Ignoring any extra columns on this row
# thread = 1 warning: parsed expected 11 columns, but didn't reach end of line on data row: 8. Ignoring any extra columns on this row
# 10-element Array{NBodySimulator.MassBody{Float64,Float64},1}:
#  NBodySimulator.MassBody{Float64,Float64}([-7.24764151699052e8, 1.063504899907968e9, 7.809572856760933e6], [-14.128701581322622, -5.667110973908211, 0.4012336501789666], 1.9885e30)
#  NBodySimulator.MassBody{Float64,Float64}([2.433425210900718e10, 4.020043340239679e10, 9.071039244422429e8], [-50744.38936160061, 28219.83112997464, 6960.534151493965], 3.30114e23)
#  NBodySimulator.MassBody{Float64,Float64}([-9.51152908270729e10, -5.130010888824722e10, 4.736254851627968e9], [16731.29471498851, -30792.27489267942, -1388.378419163475], 4.86747e24)
#  NBodySimulator.MassBody{Float64,Float64}([-1.0438988895007619e11, -1.086631485981335e11, 1.28286561544165e7], [21145.14991794887, -20564.67414180139, 2.062231176508611], 5.97237e24)
#  NBodySimulator.MassBody{Float64,Float64}([4.159306599796097e10, -2.0903353631720438e11, -5.43267249890627e9], [24654.08425561382, 6861.546285287316, -460.89497792611], 6.41712e23)
#  NBodySimulator.MassBody{Float64,Float64}([2.1692293705456952e11, -7.428141303078187e11, -1.772083459887385e9], [12381.69873135068, 4285.603674186333, -294.70251675079237], 1.898187e27)
#  NBodySimulator.MassBody{Float64,Float64}([6.583085062472236e11, -1.345308541766798e12, -2.81539806560427e9], [8140.5381275805175, 4219.942445395232, -398.0814060618552], 5.68336e26)
#  NBodySimulator.MassBody{Float64,Float64}([2.382510930024673e12, 1.7605426871032432e12, -2.4327029684089542e10], [-4097.254214987442, 5159.584892045816, 72.13036527036998], 8.68127e25)
#  NBodySimulator.MassBody{Float64,Float64}([4.3859835813554297e12, -8.926896943684296e11, -8.269605193965215e10], [1048.673550284837, 5358.952744957951, -134.5235394142934], 1.024126e26)
#  NBodySimulator.MassBody{Float64,Float64}([1.997066918166823e12, -4.681409571358568e12, -7.673288605578279e10], [5108.123595140517, 965.9128797527617, -1569.300275625834], 1.303e22)

# %%
const timespan = (0.0, 5000.0*day)
const bodies = [ 
    sun.b, 
    mercury.b, 
    venus.b, 
    earth.b, 
    mars.b, 
    #jupiter.b, 
    #saturn.b, 
    #uranus.b, 
    #neptune.b, 
    #pluto.b
]

system = NBodySimulator.GravitationalSystem(bodies, G)
simulation = NBodySimulator.NBodySimulation(system, timespan)
simresult = NBodySimulator.run_simulation(simulation)
# Out:
# WARNING: redefining constant timespan
# WARNING: redefining constant bodies
# N: 5
# Timespan: (0.0, 4.32e8)
# Boundary conditions: NBodySimulator.InfiniteBox{Float64}([-Inf, Inf, -Inf, Inf, -Inf, Inf])
# Potentials:
# Gravitational:
# 	G:6.67408e-11
# Time steps: 1155
# t: 0.0, 4.32e8

# %%
Plots.animate(simresult)
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] Array at ./boot.jl:407 [inlined]
#  [2] similar at ./array.jl:359 [inlined]
#  [3] ode_interpolant(::Float64, ::Float64, ::Array{Float64,2}, ::Array{Float64,2}, ::Array{Array{Float64,2},1}, ::OrdinaryDiffEq.Tsit5Cache{Array{Float64,2},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}, ::Nothing, ::Type{Val{0}}) at /Users/jason/.julia/packages/OrdinaryDiffEq/5igHh/src/dense/generic_dense.jl:375
#  [4] ode_interpolation(::Array{Float64,1}, ::Function, ::Nothing, ::Type{T} where T, ::DiffEqBase.NullParameters, ::Symbol) at /Users/jason/.julia/packages/OrdinaryDiffEq/5igHh/src/dense/generic_dense.jl:179
#  [5] InterpolationData at /Users/jason/.julia/packages/OrdinaryDiffEq/5igHh/src/interp_func.jl:73 [inlined]
#  [6] #_#18 at /Users/jason/.julia/packages/DiffEqBase/XoVg5/src/solutions/ode_solutions.jl:18 [inlined]
#  [7] ODESolution at /Users/jason/.julia/packages/DiffEqBase/XoVg5/src/solutions/ode_solutions.jl:18 [inlined] (repeats 2 times)
#  [8] diffeq_to_arrays(::DiffEqBase.ODESolution{Float64,3,Array{Array{Float64,2},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,2},1},1},DiffEqBase.ODEProblem{Array{Float64,2},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,NBodySimulator.var"#ode_system!#48"{Int64,Array{Any,1}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},OrdinaryDiffEq.Tsit5,OrdinaryDiffEq.InterpolationData{DiffEqBase.ODEFunction{true,NBodySimulator.var"#ode_system!#48"{Int64,Array{Any,1}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,2},1},Array{Float64,1},Array{Array{Array{Float64,2},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,2},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats}, ::Bool, ::Bool, ::Int64, ::Nothing, ::Float64, ::Tuple{Int64,Int64}, ::Array{Tuple{typeof(DiffEqBase.DEFAULT_PLOT_FUNC),Int64,Int64},1}, ::Symbol, ::Nothing) at /Users/jason/.julia/packages/DiffEqBase/XoVg5/src/solutions/solution_interface.jl:201
#  [9] macro expansion at /Users/jason/.julia/packages/DiffEqBase/XoVg5/src/solutions/solution_interface.jl:77 [inlined]
#  [10] apply_recipe(::Dict{Symbol,Any}, ::DiffEqBase.ODESolution{Float64,3,Array{Array{Float64,2},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,2},1},1},DiffEqBase.ODEProblem{Array{Float64,2},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,NBodySimulator.var"#ode_system!#48"{Int64,Array{Any,1}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},OrdinaryDiffEq.Tsit5,OrdinaryDiffEq.InterpolationData{DiffEqBase.ODEFunction{true,NBodySimulator.var"#ode_system!#48"{Int64,Array{Any,1}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,2},1},Array{Float64,1},Array{Array{Array{Float64,2},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,2},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats}) at /Users/jason/.julia/packages/RecipesBase/G4s6f/src/RecipesBase.jl:279
#  [11] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{NBodySimulator.SimulationResult{NBodySimulator.PotentialNBodySystem{NBodySimulator.MassBody{Float64,Float64}}},Float64}) at /Users/jason/.julia/packages/Plots/cc8wh/src/pipeline.jl:85
#  [12] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{NBodySimulator.SimulationResult{NBodySimulator.PotentialNBodySystem{NBodySimulator.MassBody{Float64,Float64}}},Float64}) at /Users/jason/.julia/packages/Plots/cc8wh/src/plot.jl:178
#  [13] plot(::NBodySimulator.SimulationResult{NBodySimulator.PotentialNBodySystem{NBodySimulator.MassBody{Float64,Float64}}}, ::Vararg{Any,N} where N; kw::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /Users/jason/.julia/packages/Plots/cc8wh/src/plot.jl:57
#  [14] plot(::NBodySimulator.SimulationResult{NBodySimulator.PotentialNBodySystem{NBodySimulator.MassBody{Float64,Float64}}}, ::Float64) at /Users/jason/.julia/packages/Plots/cc8wh/src/plot.jl:51
#  [15] animate(::Plots.FrameIterator, ::String; kw::Base.Iterators.Pairs{Symbol,Int64,Tuple{Symbol,Symbol},NamedTuple{(:fps, :loop),Tuple{Int64,Int64}}}) at /Users/jason/.julia/packages/Plots/cc8wh/src/animation.jl:42
#  [16] #animate#262 at /Users/jason/.julia/packages/Plots/cc8wh/src/animation.jl:51 [inlined]
#  [17] animate at /Users/jason/.julia/packages/Plots/cc8wh/src/animation.jl:51 [inlined] (repeats 2 times)
#  [18] top-level scope at In[57]:1

# %%
n = length(bodies)
plt = Plots.plot3d(
    n,
    xlim = (-2*au, 2*au),
    ylim = (-2*au, 2*au),
    zlim = (-0.5*au, 0.5*au),
    title = "Orbit",
    marker = :circle,
    legend = false,
    #linetype = :scatter3d
)

anim = Plots.@animate for i=1:30*day:5000*day
    r = NBodySimulator.get_position(simresult, i)
    push!(plt, rotl90(r)[1:n], rotl90(r)[n+1:2*n], rotl90(r)[2*n+1:3*n])
end
Plots.gif(anim, "inner.gif", fps = 30)
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/jason/workspace/space-simulator/inner.gif
# └ @ Plots /Users/jason/.julia/packages/Plots/cc8wh/src/animation.jl:98
# Plots.AnimatedGif("/Users/jason/workspace/space-simulator/inner.gif")

# %%
n = length(bodies)
anim = Plots.Animation()

for i=1:3*day:5000*day
    r = NBodySimulator.get_position(simresult, i)
    plt = Plots.plot3d(
        n,
        x = rotl90(r)[1:n],
        y = rotl90(r)[n+1:2*n],
        z = rotl90(r)[2*n+1:3*n],
        xlim = (-2*au, 2*au),
        ylim = (-2*au, 2*au),
        zlim = (-0.5*au, 0.5*au),
        title = "Orbit",
        marker = :circle,
        legend = false,
        #linetype = :scatter3d
    )
    push!(plt, rotl90(r)[1:n], rotl90(r)[n+1:2*n], rotl90(r)[2*n+1:3*n])
    Plots.frame(anim, plt)
end
Plots.gif(anim, "anim_fps30.gif", fps = 30)
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/jason/workspace/space-simulator/anim_fps30.gif
# └ @ Plots /Users/jason/.julia/packages/Plots/cc8wh/src/animation.jl:98
# Plots.AnimatedGif("/Users/jason/workspace/space-simulator/anim_fps30.gif")
